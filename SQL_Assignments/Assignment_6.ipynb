# %% [markdown]
# ## Q-1. Write an SQL query to print details of the Workers who have joined in Feb’2014.

# %% [markdown]
# select * from Worker where year(Joining_date)="2018" and month(Joining_date)="02";

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q-2. Write an SQL query to fetch duplicate records having matching data in some fields of a table.

# %% [markdown]
# select Department,count(Department) from Worker group by Department having count(Department)>1;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q-3. How to remove duplicate rows from Employees table.

# %% [markdown]
# delete c1 from Worker c1 inner join Worker c2 where c1.Salary > c2.Salary and c1.Last_Name = c2.Last_Name;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q-1. Write an SQL query to print the first three characters of  FIRST_NAME from Worker table.

# %% [markdown]
# create database assignment2;
# use assignment2;
#
# create table Worker (
# id int not null,
# First_Name varchar(15),
# Last_Name varchar(15),
# Department varchar(15),
# Salary int,
# primary key(id)
# );
#
# Insert into Worker (id,First_Name,Last_Name,Department,Salary)
# values (1,"Saish","Rane","CS",56000);
# Insert into Worker (id,First_Name,Last_Name,Department,Salary)
# values (2,"Roy","Gomes","IT",75120);
# Insert into Worker (id,First_Name,Last_Name,Department,Salary)
# values (3,"Monit","Patel","Admin",52342);
# Insert into Worker (id,First_Name,Last_Name,Department,Salary)
# values (4,"Yogesh","Mudaliyar","Electronics",63236);
# Insert into Worker (id,First_Name,Last_Name,Department,Salary)
# values (5,"Nitin","Waingankar","Admin",51353);
# Insert into Worker (id,First_Name,Last_Name,Department,Salary)
# values (6,"Nirav","Gohil","IT",45463);
# Insert into Worker (id,First_Name,Last_Name,Department,Salary)
# values (7,"Sanket","Gharge","CS",35486);
# Insert into Worker (id,First_Name,Last_Name,Department,Salary)
# values (8,"Amitabh","Bachan","Electronics",31645);
#
# select * from Worker;
#
# select substring(First_Name,1,3) from Worker;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q-2. Write an SQL query to find the position of the alphabet (‘a’) in the first name column ‘Amitabh’ from Worker table. ##

# %% [markdown]
# select position("a" in First_Name) as Character_Position from Worker where First_Name = "Amitabh"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q-3. Write an SQL query to print the name of employees having the highest salary in each department.

# %% [markdown]
# select First_Name,Last_Name,Department,Salary as MaX_Salary from Worker group by(Department) order by salary desc;

# %% [markdown]
# ![image.png](attachment:image.png)

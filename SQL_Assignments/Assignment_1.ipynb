# %% [markdown]
# ## Q-1. Write an SQL query to fetch “FIRST_NAME” from Worker table using the alias name as &lt;WORKER_NAME&gt;. ##

# %% [markdown]
# create database assignment1;
# use assignment1;
#
# create table Worker (
# id int not null,
# First_Name varchar(15),
# Last_Name varchar(15),
# primary key(id)
# );
#
# Insert into Worker (id,First_Name,Last_Name)
# values (1,"Saish","Rane");
# Insert into Worker (id,First_Name,Last_Name)
# values (2,"Roy","Gomes");
# Insert into Worker (id,First_Name,Last_Name)
# values (3,"Monit","Patel");
# Insert into Worker (id,First_Name,Last_Name)
# values (4,"Yogesh","Mudaliyar");
#
# select * from Worker;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# select First_Name as Worker_Name from Worker;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q-2. Write an SQL query to fetch unique values of DEPARTMENT from Worker table.

# %% [markdown]
# create table Worker (
# id int not null,
# First_Name varchar(15),
# Last_Name varchar(15),
# Department varchar(15),
# primary key(id)
# );
#
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (1,"Saish","Rane","CS");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (2,"Roy","Gomes","IT");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (3,"Monit","Patel","Admin");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (4,"Yogesh","Mudaliyar","Electronics");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (5,"Nitin","Waingankar","Admin");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (6,"Nirav","Gohil","IT");
#
# select distinct Department from Worker;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q-3. Write an SQL query to show the last 5 record from a table.

# %% [markdown]
# create table Worker (
# id int not null,
# First_Name varchar(15),
# Last_Name varchar(15),
# Department varchar(15),
# primary key(id)
# );
#
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (1,"Saish","Rane","CS");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (2,"Roy","Gomes","IT");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (3,"Monit","Patel","Admin");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (4,"Yogesh","Mudaliyar","Electronics");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (5,"Nitin","Waingankar","Admin");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (6,"Nirav","Gohil","IT");
# Insert into Worker (id,First_Name,Last_Name,Department)
# values (7,"Sanket","Gharge","CS");
#
# select * from Worker;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (select * from Worker order by id desc limit 5) order by id asc;

# %% [markdown]
# ![image.png](attachment:image.png)
